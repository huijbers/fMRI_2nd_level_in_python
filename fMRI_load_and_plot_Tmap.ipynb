# %%
import pandas as pd
from nilearn import plotting
# %matplotlib inline

# %%
import os
os.chdir("/Users/huijbers/Dropbox/SideProjects/student_folder (for Ruben)/fMR_with_python/ENC_HI_gt_ENC_MI/")
fn = "HAB_006_FAME_Y4_ENC_HI_gt_ENC_MI.img" 
plotting.plot_glass_brain(fn)

# %%
from nilearn import image
smoothed_img = image.smooth_img(fn, fwhm=12) 
plotting.plot_glass_brain(smoothed_img)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d2a0ced321ae> in <module>()
#       1 from nipy import load_image
# ----> 2 myimg = load_image(anatfile)
#       3
#
# NameError: name 'anatfile' is not defined

# %%
from nilearn import datasets

# haxby dataset to have EPI images and masks
haxby_dataset = datasets.fetch_haxby()

# print basic information on the dataset
print('First subject anatomical nifti image (3D) is at: %s' %
      haxby_dataset.anat[0])
print('First subject functional nifti image (4D) is at: %s' %
      haxby_dataset.func[0])  # 4D data

haxby_anat_filename = haxby_dataset.anat[0]
haxby_mask_filename = haxby_dataset.mask_vt[0]
haxby_func_filename = haxby_dataset.func[0]

# localizer dataset to have contrast maps
localizer_dataset = datasets.fetch_localizer_button_task(get_anats=True)
localizer_anat_filename = localizer_dataset.anats[0]
localizer_tmap_filename = localizer_dataset.tmaps[0]
# Out:
# Dataset created in /Users/huijbers/nilearn_data/haxby2001
#
# ...
# Downloaded 2969 of 2969 bytes (100.0%,    0.0s remaining) ...done. (2 seconds, 0 min)
# ...
# Downloaded 408 of 408 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# ...
# Downloaded 291168628 of 291168628 bytes (100.0%,    0.0s remaining) ...done. (82 seconds, 1 min)
# Extracting data from /Users/huijbers/nilearn_data/haxby2001/f33ff337e914bf7fded743c7107979f9/subj2-2010.01.14.tar.gz..... done.
# First subject anatomical nifti image (3D) is at: /Users/huijbers/nilearn_data/haxby2001/subj2/anat.nii.gz
# First subject functional nifti image (4D) is at: /Users/huijbers/nilearn_data/haxby2001/subj2/bold.nii.gz
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-319df96ce569> in <module>()
#      15
#      16 # localizer dataset to have contrast maps
# ...

# %%
plotting.plot_roi(haxby_mask_filename, bg_img=haxby_anat_filename,
                  title="plot_roi")

# %%
# Import image processing tool
from nilearn import image

# Compute the voxel_wise mean of functional images across time.
# Basically reducing the functional image from 4D to 3D
mean_haxby_img = image.mean_img(haxby_func_filename)

# Visualizing mean image (3D)
plotting.plot_epi(mean_haxby_img, title="plot_epi")
